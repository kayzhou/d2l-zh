# %% [markdown]
# 《动手学深度学习》
# ========================
#
# ```eval_rst
# .. raw:: html
#    :file: frontpage.html
# ```
#
# :begin_tab:toc
#  - [前言](chapter_preface/index.ipynb)
#  - [安装](chapter_installation/index.ipynb)
#  - [符号表示](chapter_notation/index.ipynb)
#
# :end_tab:
#
# :begin_tab:toc
#  - [*第1章 简介](chapter_introduction/index.ipynb)
#  - [第2章 预备知识](chapter_preliminaries/index.ipynb)
#  - [*第3章 线性网络](chapter_linear-networks/index.ipynb)
#  - [*第4章 多层感知机](chapter_multilayer-perceptrons/index.ipynb)
#  - [*第5章 深度学习计算](chapter_deep-learning-computation/index.ipynb)
#  - [第6章 卷积神经网络](chapter_convolutional-neural-networks/index.ipynb)
#  - [第7章 现代卷积网络](chapter_convolutional-modern/index.ipynb)
#  - [第8章 循环神经网络](chapter_recurrent-neural-networks/index.ipynb)
#  - [第9章 现代循环网络](chapter_recurrent-modern/index.ipynb)
#  - [*第10章 注意力机制](chapter_attention-mechanisms/index.ipynb)
#  - [第11章 优化算法](chapter_optimization/index.ipynb)
#  - [第12章 计算性能](chapter_computational-performance/index.ipynb)
#  - [第13章 计算机视觉](chapter_computer-vision/index.ipynb)
#  - [*第14章 自然语言处理预训练](chapter_natural-language-processing-pretraining/index.ipynb)
#  - [*第15章 自然语言处理应用](chapter_natural-language-processing-applications/index.ipynb)
#  - [第16章 深度学习工具](chapter_appendix-tools-for-deep-learning/index.ipynb)
#
# :end_tab:
#
#
# :begin_tab:toc
#  - [参考文献](chapter_references/zreferences.ipynb)
# :end_tab:
